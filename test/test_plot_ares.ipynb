# %%
import accelerator_environments.envs.ares.ARESlatticeStage3v1_9 as ares
from accelerator_environments.utils import subcell_of
import joss
import numpy as np
# Out:
# initializing ocelot...

# %%
segment = joss.Segment.from_ocelot(ares.cell)
# Out:
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.
# WARNING: Diagnostic screen was converted with default screen properties.

# %%
segment.ARLIRSBL1.delta_energy = 1e5

# %%
segment(joss.Beam.make_random())
# Out:
# Beam(n=100000, mu_x=3.2549229520925948e-09, mu_xp=5.982035441881991e-11, mu_y=-2.4437027592377208e-08, mu_yp=-5.95628885684714e-10, sigma_x=8.479166441717958e-06, sigma_xp=2.0016455904321968e-07, sigma_y=8.466281431021745e-06, sigma_yp=1.998744063970904e-07, sigma_s=0.0, sigma_p=0.0, energy=100100000.0)

# %%
segment.plot_overview()
