# %%
import accelerator_environments.envs.ares.ARESlatticeStage3v1_9 as ares
from accelerator_environments.utils import subcell_of
import joss
import numpy as np
# Out:
# initializing ocelot...

# %%
segment = joss.Segment.from_ocelot(ares.cell)
# Out:
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!
# WARNING: A diagnostic screen was converted from Ocelot and its resolution and pixel size were set to default values. You may need to adjust these!

# %%
segment.ARLIRSBL1.delta_energy = 1e5

# %%
segment(joss.Beam.make_random())
# Out:
# Beam(n=100000, mu_x=-2.3772755018331102e-08, mu_xp=-5.576711564504867e-10, mu_y=9.665078784707328e-09, mu_yp=2.1718063901769007e-10, sigma_x=8.470657998150497e-06, sigma_xp=1.9999150712980321e-07, sigma_y=8.446348897561131e-06, sigma_yp=1.9939864174195562e-07, sigma_s=0.0, sigma_p=0.0, energy=100100000.0)

# %%
segment.plot_overview()
