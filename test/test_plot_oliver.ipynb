# %%
import accelerator_environments.envs.ares.ARESlatticeStage3v1_9 as ares
from accelerator_environments.utils import subcell_of
import cheetah
import numpy as np
# Out:
# initializing ocelot...

# %%
cell = subcell_of(ares.cell, "AREASOLA1", "Drift_AREAMQZM1")
segment = cheetah.Segment.from_ocelot(cell)

# %%
segment.AREAMQZM1.k1 = 10
# segment.AREAMQZM2.k1 = 0
# segment.AREAMQZM3.k1 = 0
# segment.AREAMCVM1.angle = 0
# segment.AREAMCHM1.angle = 1e-3

# %%
coordinates = np.linspace(-1e-3, 1e-3, 3)
particles = np.array([[i, 0, 0, 0, 0, 0, 1] for i in coordinates])

# %%
segment.plot_overview(beam=cheetah.Beam(particles, 1e8), n=3)
