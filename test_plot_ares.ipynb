# %%
import accelerator_environments.envs.ares.ARESlatticeStage3v1_9 as ares
from accelerator_environments.utils import subcell_of
import joss
import numpy as np
# Out:
# initializing ocelot...

# %%
segment = joss.Segment(ares.cell)

# %%
particles = joss.generate_particles(n=10)

# %%
segment.plot_reference_particles(particles)
