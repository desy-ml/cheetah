# %%
import accelerator_environments
import gym
import joss
# Out:
# initializing ocelot...

# %%
env = gym.make("ARESEA-JOSS-v0")

# %%
env.reset()
for _ in range(10):
    env.step(env.action_space.sample())

# %%
env.segment.plot_reference_particles(env.initial_particles, resolution=0.1)

# %%
env.segment.plot_reference_particles(env.initial_particles, resolution=0.01)

# %%
env.segment.plot_reference_particles(env.initial_particles, resolution=0.001)
