# %%
import accelerator_environments
import gym
import joss
# Out:
# initializing ocelot...

# %%
env = gym.make("ARESEA-JOSS-v0")

# %%
env.reset()
for _ in range(10):
    env.step(env.action_space.sample())

# %%
print(env.read_magnets())
env.segment.plot_reference_particles(env.initial_particles, resolution=0.01)
# Out:
# [-5.71793411e-01 -1.18557815e-01  1.20799635e+00  3.57011981e-04
#   1.13926647e-04]
# 1.0510399999999984 AREAMCVM1 0.00035701198130846023
# 4.04604 AREAMCVM2 0.0
# 4.707040000000001 ARMRMCVM1 0.0
# 5.80504 ARMRMCVM2 0.0
