# %%
import accelerator_environments
import gym
import joss
# Out:
# initializing ocelot...

# %%
env = gym.make("ARESEA-JOSS-v0")

# %%
env.reset()
for _ in range(10):
    env.step(env.action_space.sample())

# %%
print(env.read_magnets())
env.segment.plot_overview(env.initial_particles, resolution=0.01)
# Out:
# [-2.69544306e-01 -1.17933732e+00  1.71241228e+00 -1.22877394e-04
#   2.20342213e-05]
