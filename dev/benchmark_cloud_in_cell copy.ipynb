# %%
import torch

import cheetah

# %%
incoming = cheetah.ParticleBeam.from_parameters(
    num_particles=100_000,
    sigma_x=torch.tensor(1e-3),
    sigma_y=torch.tensor(1e-3),
    energy=torch.tensor(1e9),
)
histogram_screen = cheetah.Screen(
    resolution=(500, 500),
    pixel_size=torch.tensor((2e-5, 2e-5)),
    is_active=True,
    method="histogram",
)
kde_screen = cheetah.Screen(
    resolution=(500, 500),
    pixel_size=torch.tensor((2e-5, 2e-5)),
    is_active=True,
    method="kde",
)
cic_screen = cheetah.Screen(
    resolution=(500, 500),
    pixel_size=torch.tensor((2e-5, 2e-5)),
    is_active=True,
    method="cloud-in-cell",
)

# %%
# %%timeit
histogram_screen.track(incoming)
reading = histogram_screen.reading
# Out:
# 3.06 ms ± 44 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
kde_screen.track(incoming)
reading = kde_screen.reading
# Out:
# 190 ms ± 1.63 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
cic_screen.track(incoming)
reading = cic_screen.reading
# Out:
# 7.91 ms ± 46.7 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
vectorized_incoming = cheetah.ParticleBeam.from_parameters(
    num_particles=10_000,
    sigma_x=torch.linspace(1e-3, 2e-3, 100),
    sigma_y=torch.tensor(1e-3),
    energy=torch.tensor(1e9),
)

# %%
# %%timeit
kde_screen.track(vectorized_incoming)
reading = kde_screen.reading
# Out:
# 2.06 s ± 63 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
cic_screen.track(vectorized_incoming)
reading = cic_screen.reading
# Out:
# 51.7 ms ± 807 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
tiny_incoming = cheetah.ParticleBeam.from_parameters(
    num_particles=10,
    sigma_x=torch.tensor(1e-3),
    sigma_y=torch.tensor(1e-3),
    energy=torch.tensor(1e9),
)
tiny_histogram_screen = cheetah.Screen(
    resolution=(3, 4),
    pixel_size=torch.tensor((2e-5, 2e-5)),
    is_active=True,
    method="histogram",
)
tiny_kde_screen = cheetah.Screen(
    resolution=(3, 4),
    pixel_size=torch.tensor((2e-5, 2e-5)),
    is_active=True,
    method="kde",
)
tiny_cic_screen = cheetah.Screen(
    resolution=(3, 4),
    pixel_size=torch.tensor((2e-5, 2e-5)),
    is_active=True,
    method="cloud-in-cell",
)

# %%
# %%timeit
tiny_histogram_screen.track(tiny_incoming)
reading = tiny_histogram_screen.reading
# Out:
# 185 μs ± 1.35 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
tiny_kde_screen.track(tiny_incoming)
reading = tiny_kde_screen.reading
# Out:
# 558 μs ± 3.19 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
# %%timeit
tiny_cic_screen.track(tiny_incoming)
reading = tiny_cic_screen.reading
# Out:
# 681 μs ± 2.46 μs per loop (mean ± std. dev. of 7 runs, 1,000 loops each)

# %%
mps_incoming = incoming.to(device="mps", dtype=torch.float32)
mps_histogram_screen = histogram_screen.to(device="mps", dtype=torch.float32)
mps_kde_screen = kde_screen.to(device="mps", dtype=torch.float32)
mps_cic_screen = cic_screen.to(device="mps", dtype=torch.float32)

# %%
# %%timeit
# mps_histogram_screen.track(mps_incoming)
# reading = mps_histogram_screen.reading

# %%
# %%timeit
mps_kde_screen.track(mps_incoming)
reading = mps_kde_screen.reading
# Out:
# 92.3 ms ± 3.62 ms per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
# %%timeit
mps_cic_screen.track(mps_incoming)
reading = mps_cic_screen.reading
# Out:
# 12.4 ms ± 35.4 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
mps_vectorized_incoming = vectorized_incoming.to(device="mps", dtype=torch.float32)

# %%
# %%timeit
mps_kde_screen.track(mps_vectorized_incoming)
reading = mps_kde_screen.reading
# Out:
# 787 ms ± 937 μs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
# %%timeit
mps_cic_screen.track(mps_vectorized_incoming)
reading = mps_cic_screen.reading
# Out:
# 25.5 ms ± 727 μs per loop (mean ± std. dev. of 7 runs, 1 loop each)

# %%
mps_tiny_incoming = tiny_incoming.to(device="mps", dtype=torch.float32)
mps_tiny_histogram_screen = tiny_histogram_screen.to(device="mps", dtype=torch.float32)
mps_tiny_kde_screen = tiny_kde_screen.to(device="mps", dtype=torch.float32)
mps_tiny_cic_screen = tiny_cic_screen.to(device="mps", dtype=torch.float32)

# %%
# %%timeit
mps_tiny_histogram_screen.track(mps_tiny_incoming)
reading = mps_tiny_histogram_screen.reading
# Out:
# 3.97 ms ± 125 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
mps_tiny_kde_screen.track(mps_tiny_incoming)
reading = mps_tiny_kde_screen.reading
# Out:
# 9.97 ms ± 64.8 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
# %%timeit
mps_tiny_cic_screen.track(mps_tiny_incoming)
reading = mps_tiny_cic_screen.reading
# Out:
# 11.5 ms ± 57.6 μs per loop (mean ± std. dev. of 7 runs, 100 loops each)
